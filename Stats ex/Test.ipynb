# %%
import pandas as pd
import numpy as np 
from scipy import stats
import statsmodels.api as sm
from statsmodels.stats.weightstats import ztest
from statsmodels.stats.proportion import proportions_ztest

from PIL import Image
from IPython.display import display, Image
#display(Image(filename=''))

# %%
#การประมาณค่าเฉลี่ยประชากรแบบจุด
display(Image(filename='pic data for test/Screenshot 2023-03-21 200440.png'))

# %%
#ex 
x = [165, 172, 157, 138, 180, 175, 159, 149, 190, 182]
x_bar = np.mean(x)
display(Image(filename='pic data for test/Screenshot 2023-03-21 201454.png'))
print(x_bar)
# Out:
# 166.7

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 202450.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 201209.png'))
print("x_bar + stats.norm.ppf(alpha/2)*var/np.sqrt(n) <= mu <= x_bar + stats.norm.isf(alpha/2)*var/np.sqrt(n)")
# Out:
# x_bar + stats.norm.ppf(alpha/2)*std/np.sqrt(n) <= mu <= x_bar + stats.norm.isf(alpha/2)*std/np.sqrt(n)

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 201324.png'))

# s = np.std([x],ddof=1)

print("n >= 30 | x_bar + stats.norm.ppf(alpha/2)*s/np.sqrt(n) <= mu <= x_bar + stats.norm.isf(alpha/2)*s/np.sqrt(n)")
# Out:
# n >= 30 | x_bar + stats.norm.ppf(alpha/2)*s/np.sqrt(n) <= mu <= x_bar + stats.norm.isf(alpha/2)*s/np.sqrt(n)

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 201408.png'))

# s = np.std([x],ddof=1)

print("n < 30 | x_bar + stats.t.ppf(alpha/2, df=n-1)*std/np.sqrt(n) <= mu <= x_bar + stats.t.isf(alpha/2, df=n-1)*std/np.sqrt(n)")
# Out:
# n < 30 | x_bar + stats.t.ppf(alpha/2, df=n-1)*std/np.sqrt(n) <= mu <= x_bar + stats.t.isf(alpha/2, df=n-1)*std/np.sqrt(n)

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 202409.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 202705.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 202726.png'))
print(" np.var([...],ddof=1")
# Out:
#  np.var([...],ddof=1

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 202928.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203034.png'))
print( " ((n-1)*(s^2))/stats.chi2.isf(alpha/2, df=n-1) < var^2 < ((n-1)*(s^2))/stats.chi2.ppf(alpha/2, df=n-1) " )
# Out:
#  ((n-1)*(s^2))/stats.chi2.isf(alpha/2, df=n-1) < var^2 < ((n-1)*(s^2))/stats.chi2.ppf(alpha/2, df=n-1)

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203310.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203412.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203428.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203605.png'))
print("z_cal,t_cal = (x_bar - mu)/(var/np.sqrt(n))")
# Out:
# z_cal,t_cal = (x_bar - mu)/(var/np.sqrt(n))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203643.png'))
print("u > mu  | p_val = stats.norm.sf(z_cal)\nu != mu | p_val = 2*stats.norm.sf(abs(z_cal))\nu < mu  | p_val = stats.norm.cdf(z_cal)")
# Out:
# u > mu  | p_val = stats.norm.sf(z_cal)
# u != mu | p_val = 2*stats.norm.sf(abs(z_cal))
# u < mu  | p_val = stats.norm.cdf(z_cal)

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 203910.png'))
display(Image(filename='pic data for test/Screenshot 2023-03-21 203926.png'))
# สูตรลัด

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 204010.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 204125.png'))
display(Image(filename='pic data for test/Screenshot 2023-03-21 204138.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 204502.png'))
print("z_cal  = (p_hat - p)/np.sqrt((p*(1-p))/n)\nz_crit = stats.norm.isf(alpha)")
# Out:
# z_cal  = (p_hat - p)/np.sqrt((p*(1-p))/n)
# z_crit = stats.norm.isf(alpha)

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 204613.png'))
# สูตรลัด

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 205457.png'))
print(" p_hat = x1+x2 / n1+n2")
print(" z_cal = ((p_hat1 - p_hat2) - P)/np.sqrt(p_hat*(1-p_hat)*(1/n1 + 1/n2))")
# Out:
#  p_hat = x1+x2 / n1+n2
#  z_cal = ((p_hat1 - p_hat2) - P)/np.sqrt(p_hat*(1-p_hat)*(1/n1 + 1/n2))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 210000.png'))
# สูตรลัด

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 210045.png'))
print(" chi2_cal = ((n-1)*(s^2))/(var^2) ; v = n-1")
# Out:
#  chi2_cal = ((n-1)*(s^2))/(var^2) ; v = n-1

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 210554.png'))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 210710.png'))
display(Image(filename='pic data for test/Screenshot 2023-03-21 210742.png'))
display(Image(filename='pic data for test/Screenshot 2023-03-21 210842.png'))
display(Image(filename='pic data for test/Screenshot 2023-03-21 211355.png'))
print(" p_val = 2*min(stats.f.sf(f_cal, dfn=n1-1, dfd=n2-1), stats.f.cdf(f_cal, dfn=n1-1, dfd=n2-1)) ")
# Out:
#  p_val = 2*min(stats.f.sf(f_cal, dfn=n1-1, dfd=n2-1), stats.f.cdf(f_cal, dfn=n1-1, dfd=n2-1))

# %%
display(Image(filename='pic data for test/Screenshot 2023-03-21 211605.png'))
print("d_bar = np.mean(before-after)\nd_var = np.var(before-after, ddof=1)\nt_cal = (d_bar-d)/np.sqrt(d_var/n)\np_val = 2*stats.t.sf(abs(t_cal), df=n-1)")
# Out:
# d_bar = np.mean(before-after)
# d_var = np.var(before-after, ddof=1)
# t_cal = (d_bar-d)/np.sqrt(d_var/n)
# p_val = 2*stats.t.sf(abs(t_cal), df=n-1)

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))

# %%
#display(Image(filename=''))
